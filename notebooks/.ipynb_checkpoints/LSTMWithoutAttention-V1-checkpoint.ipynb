# %%
import numpy as np
import gensim, logging
import csv, string
import nltk
#nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
import pandas as pd
import tensorflow as tf
import os
import pickle

num_words = 75
num_words_description = 75
directory_prefix = "../"
label_depth = 3
import random
#import gensim.downloader as api
from nltk.corpus import stopwords
from gensim.parsing.preprocessing import remove_stopwords


import tensorflow_hub as hub

embed = hub.load("https://tfhub.dev/google/tf2-preview/nnlm-en-dim128-with-normalization/1")
#embed = hub.load("https://tfhub.dev/google/Wiki-words-500/2")

embeddings = embed(["cat is on the mat", "dog is in the fog"])
embedding_dim = embeddings.shape[1]
#print(embeddings)
def get_sentence_vector(words, num_words):
    words = word_tokenize(remove_stopwords(words))
    #words = list(filter(lambda w: len(w)>2, words))
    ret = embed(words)
    ret = tf.pad(ret, tf.constant([[0, max(0, num_words-ret.shape[0]),], [0, 0]]), "CONSTANT")
    ret = ret[:num_words]
    return ret
 
with open(directory_prefix+"/class_descriptions/class_descriptions_from_patents.pickle", 'rb') as f:
    label_dict = pickle.load(f)
label_dict = {k[:label_depth]: get_sentence_vector(val.lower(), num_words_description) for k, val in label_dict.items()}
#label_dict = {k[:label_depth]: get_sentence_vector(val.lower(), num_words_description) for k, val in label_dict.items()}

label_dict_keys = set(label_dict.keys())
# Out:
# [nltk_data] Downloading package stopwords to /home/jpark/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x7f109c126f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x7f109c126f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x7f10a808c510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x7f10a808c510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function recreate_function.<locals>.restored_function_body at 0x7f109c126a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function recreate_function.<locals>.restored_function_body at 0x7f109c126a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print(embedding_dim)
# Out:
# 128

# %%
def lstm_data_generator():
    current_dataframe = pd.read_csv(directory_prefix+'/datasets/dataset.csv',sep=',', header = None).to_numpy()#, chunksize=100000)
    indices = np.random.choice(300000, 200000)
    for row in current_dataframe[indices]:
        label, description=row[0], row[1]
        lstm_input_patent = get_sentence_vector(description.lower(), num_words)
        label_vectors = [z.strip().strip('\'\"')[:label_depth] for z in label.split(',')]
        label_vectors = set([i for i in label_vectors if i in label_dict_keys])
        non_true_vectors = [label_dict[i] for i in random.sample(label_dict_keys, min(2*len(label_vectors), len(label_dict.keys()))) if i not in label_vectors]
        for l in (label_dict[i] for i in label_vectors):
            yield ({'input_1':lstm_input_patent, 'input_2':l}, {'output_binary':[1]})
        for l in non_true_vectors:
            yield ({'input_1':lstm_input_patent, 'input_2':l}, {'output_binary':[0]})

lstm_dataset = tf.data.Dataset.from_generator(lstm_data_generator, ({'input_1':tf.float64, 'input_2':tf.float64}, {'output_binary':tf.float64}), ({'input_1':tf.TensorShape([num_words, embedding_dim]), 'input_2':tf.TensorShape([num_words_description, embedding_dim])}, {'output_binary':tf.TensorShape([1])}))
lstm_dataset = lstm_dataset.batch(16, drop_remainder=True).prefetch(100).repeat()

# %%
input_lstm = tf.keras.Input(shape=(num_words, embedding_dim), name='input_1')
input_label = tf.keras.Input(shape=(num_words_description, embedding_dim), name='input_2')

patent_mask = tf.keras.layers.Masking(mask_value=0., input_shape=(num_words, embedding_dim))(input_lstm)
label_mask = tf.keras.layers.Masking(mask_value=0., input_shape=(num_words_description, embedding_dim))(input_label)

layer_size = embedding_dim*2
patent = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim, return_sequences=True))(patent_mask)
label = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim, return_sequences=True))(label_mask)

#


patent = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(layer_size//2))(patent)
patent = tf.keras.layers.GlobalAveragePooling1D()(patent)

label = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(layer_size//2))(label)
label = tf.keras.layers.GlobalAveragePooling1D()(label)
#patent = tf.keras.layers.Dense(layer_size//2)(patent)
#label =  tf.keras.layers.Dense(layer_size//2)(label)

#subtract = tf.keras.layers.Subtract()([patent, label])
#multiply = tf.keras.layers.Multiply()([patent, label])

concat = tf.keras.layers.Concatenate(axis=1)([label, patent])
dense = tf.keras.layers.Dense(int(layer_size))(concat)
dense = tf.keras.layers.Dense(int(layer_size))(dense)
dense = tf.keras.layers.Dense(int(layer_size), activation='relu')(dense)
dense = tf.keras.layers.Dense(int(layer_size), activation='relu')(dense)
dense = tf.keras.layers.Dense(int(layer_size), activation='relu')(dense)

output_binary = tf.keras.layers.Dense(1, name='output_binary')(dense)


#lstm_enforce_1 = tf.keras.layers.Dense(200, activation='relu')(patent_lstm)
#lstm_enforce_2 = tf.keras.layers.Dense(1000, name='output_2')(lstm_enforce_1)
#model = tf.keras.Model(inputs={'input_1':input_lstm, 'input_2':input_label}, outputs={'output_1':output_binary, 'output_2':lstm_enforce_2})
model = tf.keras.Model(inputs={'input_1':input_lstm, 'input_2':input_label}, outputs=[output_binary])
print(model)
# Out:
# <tensorflow.python.keras.engine.functional.Functional object at 0x7f103c472c88>

# %%
print(len(label_dict))
# Out:
# 128

# %%
#saver = tf.train.Saver(max_to_keep=4, keep_checkpoint_every_n_hours=2)
#del model
try:
    model.load_weights(directory_prefix+"checkpoints/LSTMWithoutAttention-V1.h5")
except:
    pass

model.summary()
opt = tf.optimizers.Adam(1e-5)
model.compile(loss=['binary_crossentropy'],
              optimizer=opt,
              metrics=['accuracy'], experimental_run_tf_function=False)


# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=directory_prefix+"checkpoints/LSTMWithoutAttention-V1.h5",
                                                 save_weights_only=False,
                                                 verbose=1)

class CustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        generate_prc()
prc_callback = CustomCallback()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 75, 128)]    0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 75, 128)]    0
# __________________________________________________________________________________________________
# masking_1 (Masking)             (None, 75, 128)      0           input_2[0][0]
# __________________________________________________________________________________________________
# masking (Masking)               (None, 75, 128)      0           input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 75, 256)      263168      masking_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 75, 256)      263168      masking[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 75, 128)      32896       bidirectional_1[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 75, 128)      32896       bidirectional[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           time_distributed_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 128)          0           time_distributed[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 256)          0           global_average_pooling1d_1[0][0]
#                                                                  global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          65792       concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          65792       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          65792       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          65792       dense_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          65792       dense_5[0][0]
# __________________________________________________________________________________________________
# output_binary (Dense)           (None, 1)            257         dense_6[0][0]
# ==================================================================================================
# Total params: 921,345
# Trainable params: 921,345
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def generate_prc():
    label_len = len(label_dict_keys)
    #print(label_len)
    left = [label_dict[i] for i in label_dict_keys]
    predictions = []
    left_vectors = np.array(list(label_dict_keys))
    label_vectors_vector = []
    num_tests = 1000
    def cur_gen():
        for row in pd.read_csv(directory_prefix+'datasets/test_dataset.csv',sep=',', header = None).to_numpy():
            label, description=row[0], row[1]
            label_vectors = [z.strip().strip('\'\"')[:label_depth] for z in label.split(',')]
            label_vectors = set([i for i in label_vectors if i in label_dict_keys])
            if label_vectors == set():
                continue
            label_vectors_vector.append(label_vectors)
            lstm_input_patent =  get_sentence_vector(description.lower(), num_words)
            for i in left:
                yield ({'input_1':lstm_input_patent, 'input_2':i})

    dataset = tf.data.Dataset.from_generator(cur_gen, ({'input_1':tf.float64, 'input_2':tf.float64}), ({'input_1':tf.TensorShape([num_words, embedding_dim]), 'input_2':tf.TensorShape([num_words_description, embedding_dim])}))
    dataset = dataset.batch(label_len).prefetch(50)
    predictions = model.predict(dataset, steps=num_tests, verbose=1).reshape(num_tests, label_len)
    n = 0
    d=0
    ns = []
    recalls = np.arange(0, 1.01, .01)
    ns = []
    
    for prediction, label_vectors in zip(predictions, label_vectors_vector):
        indices = np.flip(np.argsort(prediction, axis=0))
        #print(indices)
        e = [1 if i in label_vectors else 0 for i in left_vectors[indices]]
        cur = []
        total_ones = e.count(1)
        n = 0
        ones_seen = 0
        while ones_seen < total_ones:
            if e[n] == 1:
                ones_seen = ones_seen+1
            n = n+1
            cur.append((ones_seen/float(n), ones_seen/float(total_ones)))
        new_cur = []
        for r in recalls:
            max_of_larger = max([i[0] for i in cur if i[1] >= r])
            new_cur.append(max_of_larger)
        ns.append(new_cur)
        #print(max(new_cur))
        d = d+1
        #print(float(d)/7215)
        #print(np.mean(np.vstack(ns), axis=0)[0])
    p = np.mean(np.array(ns), axis=0)
    np.save("newest_ps.npy", p)
    np.save("predictions.npy", predictions)
    np.save("label_vectors_vector.npy", label_vectors_vector)
    import matplotlib.pyplot as plt
    plt.plot(recalls, p)
    plt.ylim(0, 1)
    plt.xlim(0, 1)
    plt.margins(0.1)
    #plt.xticks(range(len(distribution_dict.keys()))[::50], new_x[::50], rotation='vertical')
    plt.ylabel('Precision', fontsize=16)
    plt.xlabel('Recall', fontsize=16)
    plt.tight_layout()
    plt.show()
    #print(p) 
    plt.savefig('binary_prc1.eps', format='eps')

# %%
history = model.fit(lstm_dataset, epochs=50, steps_per_epoch=3000, callbacks=[cp_callback, prc_callback])
# Out:
# Epoch 1/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3967 - accuracy: 0.8249
# Epoch 00001: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 112s 37ms/step - loss: 0.3967 - accuracy: 0.8249
# Epoch 2/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3976 - accuracy: 0.8245
# Epoch 00002: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 35s 35ms/step
# 3000/3000 [==============================] - 107s 36ms/step - loss: 0.3976 - accuracy: 0.8245
# Epoch 3/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3982 - accuracy: 0.8248
# Epoch 00003: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 105s 35ms/step - loss: 0.3981 - accuracy: 0.8248
# Epoch 4/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3942 - accuracy: 0.8261
# Epoch 00004: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3943 - accuracy: 0.8261
# Epoch 5/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.4142 - accuracy: 0.8144
# Epoch 00005: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.4142 - accuracy: 0.8144
# Epoch 6/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3827 - accuracy: 0.8280
# Epoch 00006: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3827 - accuracy: 0.8280
# Epoch 7/50
# 2998/3000 [============================>.] - ETA: 0s - loss: 0.3772 - accuracy: 0.8334
# Epoch 00007: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3771 - accuracy: 0.8335
# Epoch 8/50
# 2998/3000 [============================>.] - ETA: 0s - loss: 0.3781 - accuracy: 0.8331
# Epoch 00008: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3781 - accuracy: 0.8331
# Epoch 9/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3747 - accuracy: 0.8348
# Epoch 00009: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 105s 35ms/step - loss: 0.3747 - accuracy: 0.8349
# Epoch 10/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3847 - accuracy: 0.8307
# Epoch 00010: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3847 - accuracy: 0.8307
# Epoch 11/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3867 - accuracy: 0.8321
# Epoch 00011: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3867 - accuracy: 0.8321
# Epoch 12/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3664 - accuracy: 0.8382
# Epoch 00012: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 105s 35ms/step - loss: 0.3664 - accuracy: 0.8382
# Epoch 13/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3749 - accuracy: 0.8368
# Epoch 00013: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3749 - accuracy: 0.8368
# Epoch 14/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3789 - accuracy: 0.8363
# Epoch 00014: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3791 - accuracy: 0.8364
# Epoch 15/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3705 - accuracy: 0.8395
# Epoch 00015: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3706 - accuracy: 0.8395
# Epoch 16/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3740 - accuracy: 0.8363
# Epoch 00016: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3740 - accuracy: 0.8363
# Epoch 17/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3747 - accuracy: 0.8382
# Epoch 00017: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3747 - accuracy: 0.8382
# Epoch 18/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3723 - accuracy: 0.8407
# Epoch 00018: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 103s 34ms/step - loss: 0.3723 - accuracy: 0.8407
# Epoch 19/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3751 - accuracy: 0.8385
# Epoch 00019: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3752 - accuracy: 0.8384
# Epoch 20/50
# 2998/3000 [============================>.] - ETA: 0s - loss: 0.3739 - accuracy: 0.8405
# Epoch 00020: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3738 - accuracy: 0.8406
# Epoch 21/50
# 2998/3000 [============================>.] - ETA: 0s - loss: 0.3587 - accuracy: 0.8472
# Epoch 00021: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 103s 34ms/step - loss: 0.3587 - accuracy: 0.8471
# Epoch 22/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3621 - accuracy: 0.8442
# Epoch 00022: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3620 - accuracy: 0.8442
# Epoch 23/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.8364
# Epoch 00023: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3684 - accuracy: 0.8364
# Epoch 24/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3635 - accuracy: 0.8459
# Epoch 00024: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3635 - accuracy: 0.8459
# Epoch 25/50
# 2998/3000 [============================>.] - ETA: 0s - loss: 0.3688 - accuracy: 0.8427
# Epoch 00025: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3688 - accuracy: 0.8427
# Epoch 26/50
# 2998/3000 [============================>.] - ETA: 0s - loss: 0.3622 - accuracy: 0.8453
# Epoch 00026: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3622 - accuracy: 0.8454
# Epoch 27/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3975 - accuracy: 0.8357
# Epoch 00027: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3975 - accuracy: 0.8357
# Epoch 28/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3641 - accuracy: 0.8403
# Epoch 00028: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3641 - accuracy: 0.8403
# Epoch 29/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3588 - accuracy: 0.8469
# Epoch 00029: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 105s 35ms/step - loss: 0.3588 - accuracy: 0.8469
# Epoch 30/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3774 - accuracy: 0.8412
# Epoch 00030: saving model to ../checkpoints/LSTMWithoutAttention-V1.h5
# 1000/1000 [==============================] - 34s 34ms/step
# 3000/3000 [==============================] - 104s 35ms/step - loss: 0.3774 - accuracy: 0.8412
# Epoch 31/50
# 2774/3000 [==========================>...] - ETA: 5s - loss: 0.3558 - accuracy: 0.8493

# %%
generate_prc()
# Out:
# 1000/1000 [==============================] - 34s 34ms/step
