# %%
import numpy as np
import gensim, logging
import csv, string
import nltk
#nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
import pandas as pd
import tensorflow as tf
import os
import pickle

num_words = 200
num_words_description = 200
directory_prefix = "../"
label_depth = 3
import random
#import gensim.downloader as api
from nltk.corpus import stopwords
from gensim.parsing.preprocessing import remove_stopwords


import tensorflow_hub as hub

embed = hub.load("https://tfhub.dev/google/tf2-preview/nnlm-en-dim128-with-normalization/1")
#embed = hub.load("https://tfhub.dev/google/Wiki-words-500/2")

embeddings = embed(["cat is on the mat", "dog is in the fog"])
embedding_dim = embeddings.shape[1]
#print(embeddings)
def get_sentence_vector(words, num_words):
    words = word_tokenize(remove_stopwords(words))
    #words = list(filter(lambda w: len(w)>2, words))
    ret = embed(words)
    ret = tf.pad(ret, tf.constant([[0, max(0, num_words-ret.shape[0]),], [0, 0]]), "CONSTANT")
    ret = ret[:num_words]
    return ret
 
with open(directory_prefix+"/class_descriptions/class_descriptions_from_patents.pickle", 'rb') as f:
    label_dict = pickle.load(f)
label_dict = {k[:label_depth]: get_sentence_vector(val.lower(), num_words_description) for k, val in label_dict.items()}
#label_dict = {k[:label_depth]: get_sentence_vector(val.lower(), num_words_description) for k, val in label_dict.items()}

label_dict_keys = set(label_dict.keys())
# Out:
# [nltk_data] Downloading package stopwords to /home/jpark/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(embedding_dim)
# Out:
# 128

# %%
number_occurences=1000
def lstm_data_generator():
    occurences = {k:0 for k in label_dict.keys()}
    current_dataframe = pd.read_csv(directory_prefix+'/datasets/items2.csv',sep=',', header = None).to_numpy()#, chunksize=100000)
    indices = np.random.choice(len(current_dataframe), len(current_dataframe)//2)
    for row in current_dataframe[indices]:
        label, description=row[0], row[1]
        lstm_input_patent = get_sentence_vector(description.lower(), num_words)
        label_vectors = [z.strip().strip('\'\"')[:label_depth] for z in label.split(',')]
        label_vectors = set([i for i in label_vectors if i in label_dict_keys])
        non_true_vectors = set([i for i in random.sample(label_dict_keys, min(len(label_vectors), len(label_dict.keys()))) if i not in label_vectors])
        for l, k in zip((label_dict[i] for i in label_vectors), label_vectors):
            if occurences[k] >= number_occurences:
                continue
            occurences[k] +=1
            yield ({'input_1':lstm_input_patent, 'input_2':l}, {'output_binary':[1]})
        for l, k in zip((label_dict[i] for i in non_true_vectors), non_true_vectors):
            if occurences[k] >= number_occurences:
                continue
            occurences[k] +=1
            yield ({'input_1':lstm_input_patent, 'input_2':l}, {'output_binary':[0]})
        if sum(occurences.values()) >= len(label_dict)*(number_occurences-4):
            print("\n\ndone with occurences\n\n")
            print(occurences)
            return

lstm_dataset = tf.data.Dataset.from_generator(lstm_data_generator, ({'input_1':tf.float64, 'input_2':tf.float64}, {'output_binary':tf.float64}), ({'input_1':tf.TensorShape([num_words, embedding_dim]), 'input_2':tf.TensorShape([num_words_description, embedding_dim])}, {'output_binary':tf.TensorShape([1])}))
lstm_dataset = lstm_dataset.batch(16, drop_remainder=True).prefetch(100).repeat()

# %%
input_lstm = tf.keras.Input(shape=(num_words, embedding_dim), name='input_1')
input_label = tf.keras.Input(shape=(num_words_description, embedding_dim), name='input_2')

patent_mask = tf.keras.layers.Masking(mask_value=0., input_shape=(num_words, embedding_dim))(input_lstm)
label_mask = tf.keras.layers.Masking(mask_value=0., input_shape=(num_words_description, embedding_dim))(input_label)

layer_size = embedding_dim*3
patent = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim, return_sequences=True))(patent_mask)
label = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim, return_sequences=True))(label_mask)

#


patent = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(layer_size))(patent)
patent = tf.keras.layers.GlobalAveragePooling1D()(patent)

label = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(layer_size))(label)
label = tf.keras.layers.GlobalAveragePooling1D()(label)
#patent = tf.keras.layers.Dense(layer_size//2)(patent)
#label =  tf.keras.layers.Dense(layer_size//2)(label)

#subtract = tf.keras.layers.Subtract()([patent, label])
#multiply = tf.keras.layers.Multiply()([patent, label])

concat = tf.keras.layers.Concatenate(axis=1)([label, patent])
dense = tf.keras.layers.Dense(int(layer_size)*2)(concat)
dense = tf.keras.layers.Dense(int(layer_size)*2)(dense)
dense = tf.keras.layers.Dense(int(layer_size)*2, activation='relu')(dense)
dense = tf.keras.layers.Dense(int(layer_size)*2, activation='relu')(dense)
dense = tf.keras.layers.Dense(int(layer_size)*2, activation='relu')(dense)

output_binary = tf.keras.layers.Dense(1, name='output_binary')(dense)


#lstm_enforce_1 = tf.keras.layers.Dense(200, activation='relu')(patent_lstm)
#lstm_enforce_2 = tf.keras.layers.Dense(1000, name='output_2')(lstm_enforce_1)
#model = tf.keras.Model(inputs={'input_1':input_lstm, 'input_2':input_label}, outputs={'output_1':output_binary, 'output_2':lstm_enforce_2})
model = tf.keras.Model(inputs={'input_1':input_lstm, 'input_2':input_label}, outputs=[output_binary])
print(model)
# Out:
# <tensorflow.python.keras.engine.functional.Functional object at 0x7fe0a3e63898>

# %%
print(len(label_dict))
# Out:
# 128

# %%
#saver = tf.train.Saver(max_to_keep=4, keep_checkpoint_every_n_hours=2)
#del model
try:
    model.load_weights(directory_prefix+"checkpoints/LSTMWithoutAttention-V1NewDataset.h5")
except:
    pass

model.summary()
opt = tf.optimizers.Adam(1e-5)
model.compile(loss=['binary_crossentropy'],
              optimizer=opt,
              metrics=['accuracy'], experimental_run_tf_function=False)


# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=directory_prefix+"checkpoints/LSTMWithoutAttention-V1NewDataset.h5",
                                                 save_weights_only=False,
                                                 verbose=1)

class CustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        generate_prc()
prc_callback = CustomCallback()
# Out:
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 200, 128)]   0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 200, 128)]   0
# __________________________________________________________________________________________________
# masking_9 (Masking)             (None, 200, 128)     0           input_2[0][0]
# __________________________________________________________________________________________________
# masking_8 (Masking)             (None, 200, 128)     0           input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_9 (Bidirectional) (None, 200, 256)     263168      masking_9[0][0]
# __________________________________________________________________________________________________
# bidirectional_8 (Bidirectional) (None, 200, 256)     263168      masking_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 200, 384)     98688       bidirectional_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 200, 384)     98688       bidirectional_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_9 (Glo (None, 384)          0           time_distributed_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_8 (Glo (None, 384)          0           time_distributed_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 768)          0           global_average_pooling1d_9[0][0]
#                                                                  global_average_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 768)          590592      concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 768)          590592      dense_30[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 768)          590592      dense_31[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 768)          590592      dense_32[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 768)          590592      dense_33[0][0]
# __________________________________________________________________________________________________
# output_binary (Dense)           (None, 1)            769         dense_34[0][0]
# ==================================================================================================
# Total params: 3,677,441
# Trainable params: 3,677,441
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
current_dataframe = pd.read_csv(directory_prefix+'/datasets/items1.csv',sep=',', header = None).to_numpy()#, chunksize=100000)
#indices = np.random.choice(300000, 10000)
occurences={k:0 for k in label_dict_keys}
for row in current_dataframe:
    label, description=row[0], row[1]
    lstm_input_patent = get_sentence_vector(description.lower(), num_words)
    label_vectors = [z.strip().strip('\'\"')[:label_depth] for z in label.split(',')]
    label_vectors = set([i for i in label_vectors if i in label_dict_keys])
    for i in label_vectors:
        occurences[i] += 1
print(occurences)

# %%
n = 0
d=0
recalls = np.arange(0, 1.01, .01)
ns = []
prediction = sorted(occurences.keys(), key=lambda x: occurences[x])[::-1]
print(prediction)
for row in pd.read_csv(directory_prefix+'datasets/items1.csv',sep=',', header = None).to_numpy():
    label, description=row[0], row[1]
    label_vectors = [z.strip().strip('\'\"')[:label_depth] for z in label.split(',')]
    label_vectors = set([i for i in label_vectors if i in label_dict_keys])
    if label_vectors == set():
        continue
    e = [1 if i in label_vectors else 0 for i in prediction]
    cur = []
    total_ones = e.count(1)
    n = 0
    ones_seen = 0
    while ones_seen < total_ones:
        if e[n] == 1:
            ones_seen = ones_seen+1
        n = n+1
        cur.append((ones_seen/float(n), ones_seen/float(total_ones)))
    new_cur = []
    for r in recalls:
        max_of_larger = max([i[0] for i in cur if i[1] >= r])
        new_cur.append(max_of_larger)
    ns.append(new_cur)

p_baseline = np.mean(np.array(ns), axis=0)
import matplotlib.pyplot as plt
plt.plot(recalls, p_baseline)
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.margins(0.1)
#plt.xticks(range(len(distribution_dict.keys()))[::50], new_x[::50], rotation='vertical')
plt.ylabel('Precision', fontsize=16)
plt.xlabel('Recall', fontsize=16)
plt.tight_layout()
plt.show()
#print(p) 
plt.savefig('binary_prc1.eps', format='eps')
# Out:
# ['H01', 'H04', 'Y10', 'A61', 'Y02', 'G01', 'G06', 'G11', 'G02', 'C12', 'G03', 'H02', 'B01', 'F16', 'C07', 'B60', 'H03', 'B65', 'H05', 'A01', 'G09', 'B29', 'C09', 'C08', 'F01', 'F02', 'A47', 'B82', 'C01', 'B23', 'E04', 'C23', 'F05', 'B64', 'B41', 'A23', 'E21', 'B32', 'F24', 'F04', 'F25', 'C22', 'B25', 'F21', 'B62', 'F28', 'A63', 'F41', 'C04', 'C03', 'C02', 'B22', 'G07', 'A45', 'G10', 'C10', 'G08', 'B05', 'C11', 'F03', 'F23', 'D06', 'B21', 'B66', 'E05', 'G21', 'D21', 'G05', 'E02', 'C21', 'E01', 'A41', 'F42', 'G16', 'B03', 'B63', 'B81', 'E03', 'B08', 'E06', 'B42', 'B27', 'A43', 'D04', 'C30', 'C25', 'B26', 'A62', 'F17', 'B33', 'B02', 'B07', 'B28', 'B30', 'B67', 'B04', 'D10', 'D07', 'D01', 'F26', 'B44', 'A44', 'F15', 'B24', 'C05', 'G04', 'D05', 'A46', 'B43', 'B09', 'D03', 'F27', 'B06', 'F22', 'Y04', 'D02', 'A42', 'B61', 'C06', 'B68', 'A21', 'C13', 'B31', 'C40', 'C14', 'A24', 'A22', 'G12']

# %%
def generate_prc():
    label_len = len(label_dict_keys)
    #print(label_len)
    left = [label_dict[i] for i in label_dict_keys]
    predictions = []
    left_vectors = np.array(list(label_dict_keys))
    label_vectors_vector = []
    num_tests = 3000
    def cur_gen():
        current_dataframe = pd.read_csv(directory_prefix+'datasets/test_dataset.csv',sep=',', header = None).to_numpy()#, chunksize=100000)
        indices = np.random.choice(len(current_dataframe), len(current_dataframe)-1)
        for row in current_dataframe[indices]:
            label, description=row[0], row[1]
            label_vectors = [z.strip().strip('\'\"')[:label_depth] for z in label.split(',')]
            label_vectors = set([i for i in label_vectors if i in label_dict_keys])
            if label_vectors == set():
                continue
            label_vectors_vector.append(label_vectors)
            lstm_input_patent =  get_sentence_vector(description.lower(), num_words)
            for i in left:
                yield ({'input_1':lstm_input_patent, 'input_2':i})

    dataset = tf.data.Dataset.from_generator(cur_gen, ({'input_1':tf.float64, 'input_2':tf.float64}), ({'input_1':tf.TensorShape([num_words, embedding_dim]), 'input_2':tf.TensorShape([num_words_description, embedding_dim])}))
    dataset = dataset.batch(label_len).prefetch(50)
    predictions = model.predict(dataset, steps=num_tests, verbose=1).reshape(num_tests, label_len)
    n = 0
    d=0
    recalls = np.arange(0, 1.01, .01)
    ns = []
    
    for prediction, label_vectors in zip(predictions, label_vectors_vector):
        indices = np.flip(np.argsort(prediction, axis=0))
        #print(indices)
        e = [1 if i in label_vectors else 0 for i in left_vectors[indices]]
        cur = []
        total_ones = e.count(1)
        n = 0
        ones_seen = 0
        while ones_seen < total_ones:
            if e[n] == 1:
                ones_seen = ones_seen+1
            n = n+1
            cur.append((ones_seen/float(n), ones_seen/float(total_ones)))
        new_cur = []
        for r in recalls:
            max_of_larger = max([i[0] for i in cur if i[1] >= r])
            new_cur.append(max_of_larger)
        ns.append(new_cur)
        #print(max(new_cur))
        d = d+1
        #print(float(d)/7215)
        #print(np.mean(np.vstack(ns), axis=0)[0])
    p = np.mean(np.array(ns), axis=0)
    import matplotlib.pyplot as plt
    plt.plot(recalls, p)
    plt.plot(recalls, p_baseline, 'r')
    plt.ylim(0, 1)
    plt.xlim(0, 1)
    plt.margins(0.1)
    #plt.xticks(range(len(distribution_dict.keys()))[::50], new_x[::50], rotation='vertical')
    plt.ylabel('Precision', fontsize=16)
    plt.xlabel('Recall', fontsize=16)
    plt.tight_layout()
    plt.show()
    #print(p) 
    plt.savefig('binary_prc1.eps', format='eps')
generate_prc()
# Out:
# 3000/3000 [==============================] - 142s 47ms/step

# %%
history = model.fit(lstm_dataset, epochs=50, steps_per_epoch=3000, callbacks=[cp_callback, prc_callback])
# Out:
# Epoch 1/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2922 - accuracy: 0.8968
# Epoch 00001: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 287s 96ms/step - loss: 0.2922 - accuracy: 0.8968
# Epoch 2/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.2836 - accuracy: 0.8983
# Epoch 00002: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 281s 94ms/step - loss: 0.2835 - accuracy: 0.8983
# Epoch 3/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2862 - accuracy: 0.8923
# Epoch 00003: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 146s 49ms/step
# 3000/3000 [==============================] - 284s 95ms/step - loss: 0.2862 - accuracy: 0.8923
# Epoch 4/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.8907
# Epoch 00004: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 146s 49ms/step
# 3000/3000 [==============================] - 287s 96ms/step - loss: 0.2944 - accuracy: 0.8907
# Epoch 5/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3124 - accuracy: 0.8874
# Epoch 00005: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 142s 47ms/step
# 3000/3000 [==============================] - 280s 93ms/step - loss: 0.3124 - accuracy: 0.8874
# Epoch 6/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2933 - accuracy: 0.8910
# Epoch 00006: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 146s 49ms/step
# 3000/3000 [==============================] - 282s 94ms/step - loss: 0.2933 - accuracy: 0.8910
# Epoch 7/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2821 - accuracy: 0.8968
# Epoch 00007: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 283s 94ms/step - loss: 0.2821 - accuracy: 0.8968
# Epoch 8/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.2865 - accuracy: 0.8960
# Epoch 00008: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 147s 49ms/step
# 3000/3000 [==============================] - 288s 96ms/step - loss: 0.2865 - accuracy: 0.8960
# Epoch 9/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3082 - accuracy: 0.8868
# Epoch 00009: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 146s 49ms/step
# 3000/3000 [==============================] - 287s 96ms/step - loss: 0.3082 - accuracy: 0.8868
# Epoch 10/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3003 - accuracy: 0.8939
# Epoch 00010: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 146s 49ms/step
# 3000/3000 [==============================] - 283s 94ms/step - loss: 0.3003 - accuracy: 0.8939
# Epoch 11/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.2740 - accuracy: 0.8992
# Epoch 00011: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 146s 49ms/step
# 3000/3000 [==============================] - 283s 94ms/step - loss: 0.2741 - accuracy: 0.8991
# Epoch 12/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2890 - accuracy: 0.8939
# Epoch 00012: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 147s 49ms/step
# 3000/3000 [==============================] - 286s 95ms/step - loss: 0.2890 - accuracy: 0.8939
# Epoch 13/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2773 - accuracy: 0.8950
# Epoch 00013: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 144s 48ms/step
# 3000/3000 [==============================] - 286s 95ms/step - loss: 0.2773 - accuracy: 0.8950
# Epoch 14/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2741 - accuracy: 0.9001
# Epoch 00014: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 146s 49ms/step
# 3000/3000 [==============================] - 285s 95ms/step - loss: 0.2741 - accuracy: 0.9001
# Epoch 15/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2804 - accuracy: 0.8973
# Epoch 00015: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 144s 48ms/step
# 3000/3000 [==============================] - 281s 94ms/step - loss: 0.2804 - accuracy: 0.8973
# Epoch 16/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.8905
# Epoch 00016: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 147s 49ms/step
# 3000/3000 [==============================] - 284s 95ms/step - loss: 0.2947 - accuracy: 0.8905
# Epoch 17/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2837 - accuracy: 0.8954
# Epoch 00017: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 285s 95ms/step - loss: 0.2837 - accuracy: 0.8954
# Epoch 18/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.2921 - accuracy: 0.8925
# Epoch 00018: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 146s 49ms/step
# 3000/3000 [==============================] - 286s 95ms/step - loss: 0.2920 - accuracy: 0.8926
# Epoch 19/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.2924 - accuracy: 0.8902
# Epoch 00019: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 147s 49ms/step
# 3000/3000 [==============================] - 284s 95ms/step - loss: 0.2923 - accuracy: 0.8902
# Epoch 20/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.2859 - accuracy: 0.8955
# Epoch 00020: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 281s 94ms/step - loss: 0.2858 - accuracy: 0.8955
# Epoch 21/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8971
# Epoch 00021: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 286s 95ms/step - loss: 0.2799 - accuracy: 0.8971
# Epoch 22/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2851 - accuracy: 0.8946
# Epoch 00022: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 286s 95ms/step - loss: 0.2851 - accuracy: 0.8946
# Epoch 23/50
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 284s 95ms/step - loss: 0.2845 - accuracy: 0.9009
# Epoch 24/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3132 - accuracy: 0.8908
# Epoch 00024: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
#  385/3000 [==>...........................] - ETA: 2:17
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 282s 94ms/step - loss: 0.3132 - accuracy: 0.8907
# Epoch 25/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2858 - accuracy: 0.9015
# Epoch 00025: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 147s 49ms/step
# 3000/3000 [==============================] - 284s 95ms/step - loss: 0.2858 - accuracy: 0.9015
# Epoch 26/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.8961
# Epoch 00026: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 146s 49ms/step
# 3000/3000 [==============================] - 287s 96ms/step - loss: 0.2832 - accuracy: 0.8961
# Epoch 27/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.2913 - accuracy: 0.8910
# Epoch 00027: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.2824 - accuracy: 0.8919
# Epoch 00028: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 144s 48ms/step
# 3000/3000 [==============================] - 281s 94ms/step - loss: 0.2824 - accuracy: 0.8920
# Epoch 29/50
# 1043/3000 [=========>....................] - ETA: 1:25 - loss: 0.2767 - accuracy: 0.9027
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2984 - accuracy: 0.8958
# Epoch 00032: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 2417/3000 [=======================>......] - ETA: 28s
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 282s 94ms/step - loss: 0.2801 - accuracy: 0.8998
# Epoch 35/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2748 - accuracy: 0.9005
# Epoch 00035: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 146s 49ms/step
# 3000/3000 [==============================] - 287s 96ms/step - loss: 0.2748 - accuracy: 0.9005
# Epoch 36/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.9000
# Epoch 00036: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 283s 94ms/step - loss: 0.2717 - accuracy: 0.9000
# Epoch 37/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2954 - accuracy: 0.8900
# Epoch 00037: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 143s 48ms/step
# 3000/3000 [==============================] - 279s 93ms/step - loss: 0.2954 - accuracy: 0.8900
# Epoch 38/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.2696 - accuracy: 0.9016
# Epoch 00038: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 146s 49ms/step
# 3000/3000 [==============================] - 282s 94ms/step - loss: 0.2695 - accuracy: 0.9016
# Epoch 39/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.2699 - accuracy: 0.8994
# Epoch 00039: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 1377/3000 [============>.................] - ETA: 1:18
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2938 - accuracy: 0.8961
# Epoch 00041: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 282s 94ms/step - loss: 0.2938 - accuracy: 0.8961
# Epoch 42/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.2743 - accuracy: 0.9024
# Epoch 00042: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 143s 48ms/step
# 3000/3000 [==============================] - 279s 93ms/step - loss: 0.2743 - accuracy: 0.9024
# Epoch 43/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2806 - accuracy: 0.8993
# Epoch 00043: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 3000/3000 [==============================] - 145s 48ms/step
# 3000/3000 [==============================] - 284s 95ms/step - loss: 0.2806 - accuracy: 0.8993
# Epoch 44/50
# 3000/3000 [==============================] - 144s 48ms/step
# 3000/3000 [==============================] - 284s 95ms/step - loss: 0.3067 - accuracy: 0.8993
# Epoch 45/50
# 2999/3000 [============================>.] - ETA: 0s - loss: 0.3262 - accuracy: 0.8964
# Epoch 00045: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
#  904/3000 [========>.....................] - ETA: 1:44
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 3000/3000 [==============================] - 141s 47ms/step
# 3000/3000 [==============================] - 282s 94ms/step - loss: 0.2859 - accuracy: 0.8950
# Epoch 49/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.8945
# Epoch 00049: saving model to ../checkpoints/LSTMWithoutAttention-V1NewDataset.h5
# 1903/3000 [==================>...........] - ETA: 52s
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
generate_prc()
# Out:
# 3000/3000 [==============================] - 142s 47ms/step
